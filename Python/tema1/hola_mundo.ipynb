# %% [markdown]
# # PROGRAMA DE MARKDOWN EN IPYNB DE PRUEBA
# ## HOLA MUNDO CRUEL

# %%
print ("MI BOMBOOOO")
# Out:
# MI BOMBOOOO

# %% [markdown]
# ##  Ejemplo de identacion

# %%
nombre = "anibal"
if(nombre == "anibal"):
    print("Holaaaaaaaa")
else:
    print("Hola,¿como tu te llama?")
# Out:
# Holaaaaaaaa

# %% [markdown]
# # Comentarios de código

# %%
# print ("este no se ve")
print ("este si se ve")
# Out:
# este si se ve

# %% [markdown]
# # COMENTARIO EN FUNCIONES
# # DOCUMENTACION DE FUNCIÓN CON HELP()

# %%
def me_puedo_ir_a_casa(hora_en_num):
    """ function: me_puedo_ir_a_casa
    comp
    ara si la hora pasada como argumento es mayor que un número y imprime por pantalla Sí o no
    arg1:hora_en_num: int
    """
    if(hora_en_num > 15):  
        print ("si")
    else:
        print("no")

# %%
me_puedo_ir_a_casa(16)
help(me_puedo_ir_a_casa)
# Out:
# si
# Help on function me_puedo_ir_a_casa in module __main__:
#
# me_puedo_ir_a_casa(hora_en_num)
#     function: me_puedo_ir_a_casa
#     comprara si la hora pasada como argumento es mayor que un número y imprime por pantalla Sí o no
#     arg1:hora_en_num: int
